# %%
import polars as pl
import pandas as pd
import os
import csv
from google.colab import drive
import math
from collections import Counter, defaultdict
import os

# %%
drive.mount('/content/drive')

fb_posts = '/content/drive/My Drive/Presidential Election Data/2024_fb_posts_president_scored_anon.csv'
fb_ads = '/content/drive/My Drive/Presidential Election Data/2024_fb_ads_president_scored_anon.csv'
tw_posts = '/content/drive/My Drive/Presidential Election Data/2024_tw_posts_president_scored_anon.csv'
# Out:
# Mounted at /content/drive

# %%
def analyze_polars_dataset(df: pl.DataFrame):
    print("===== General Dataset Summary =====\n")

    for col in df.columns:
        col_data = df[col]
        print(f"Column: {col}")
        non_null = col_data.drop_nulls()

        if col_data.dtype.is_numeric():
            print(f"  Count: {non_null.len()}")
            print(f"  Mean: {non_null.mean()}")
            print(f"  Min: {non_null.min()}")
            print(f"  Max: {non_null.max()}")
            print(f"  Stddev: {non_null.std()}")
        else:
            unique_vals = non_null.unique()
            print(f"  Count: {non_null.len()}")
            print(f"  Unique values: {unique_vals.len()}")

            if not non_null.is_empty():
                freq_df = non_null.value_counts().sort("count", descending=True)
                top_val = freq_df[0][col].item()       # get raw string
                top_count = freq_df[0]["count"].item() # get count as int
                print(f"  Most frequent: {top_val} (appears {top_count} times)")

        print()

# %%
df_ads = pl.read_csv(fb_ads)

analyze_polars_dataset(df_ads)
# Out:
# ===== General Dataset Summary =====
#
# Column: page_id
#   Count: 246745
#   Unique values: 4475
#   Most frequent: 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d (appears 55503 times)
#
# Column: ad_id
#   Count: 246745
#   Unique values: 246745
#   Most frequent: 1cec37d522e22202167e2ead1da7d5f9f8aa0572eb0d6fd4b0abd00442c15494 (appears 1 times)
#
# Column: ad_creation_time
#   Count: 246745
#   Unique values: 547
#   Most frequent: 2024-10-27 (appears 8619 times)
#
# Column: bylines
#   Count: 245736
#   Unique values: 3790
#   Most frequent: HARRIS FOR PRESIDENT (appears 49788 times)
#
# Column: currency
#   Count: 246745
#   Unique values: 18
#   Most frequent: USD (appears 246599 times)
#
# Column: delivery_by_region
#   Count: 246745
#   Unique values: 141122
#   Most frequent: {} (appears 30989 times)
#
# Column: demographic_distribution
#   Count: 246745
#   Unique values: 215622
#   Most frequent: {} (appears 30989 times)
#
# Column: estimated_audience_size
#   Count: 246745
#   Mean: 556462.8559687126
#   Min: 0
#   Max: 1000001
#   Stddev: 409864.75882290734
#
# Column: estimated_impressions
#   Count: 246745
#   Mean: 45601.52595189366
#   Min: 499
#   Max: 1000000
#   Stddev: 136790.7699010426
#
# Column: estimated_spend
#   Count: 246745
#   Mean: 1061.2914344768892
#   Min: 49
#   Max: 474999
#   Stddev: 4992.560748793634
#
# Column: publisher_platforms
#   Count: 246745
#   Unique values: 9
#   Most frequent: ['facebook', 'instagram'] (appears 214434 times)
#
# Column: illuminating_scored_message
#   Count: 246745
#   Unique values: 26338
#   Most frequent: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855 (appears 5972 times)
#
# Column: illuminating_mentions
#   Count: 246745
#   Unique values: 278
#   Most frequent: [] (appears 73205 times)
#
# Column: scam_illuminating
#   Count: 246745
#   Mean: 0.07163265719670105
#   Min: 0
#   Max: 1
#   Stddev: 0.25787921423700266
#
# Column: election_integrity_Truth_illuminating
#   Count: 246745
#   Mean: 0.05008814768283045
#   Min: 0
#   Max: 1
#   Stddev: 0.21812729763428282
#
# Column: advocacy_msg_type_illuminating
#   Count: 246745
#   Mean: 0.5486311779367363
#   Min: 0
#   Max: 1
#   Stddev: 0.49763039712576856
#
# Column: issue_msg_type_illuminating
#   Count: 246745
#   Mean: 0.38164907090315914
#   Min: 0
#   Max: 1
#   Stddev: 0.485792151038562
#
# Column: attack_msg_type_illuminating
#   Count: 246745
#   Mean: 0.27185555938316885
#   Min: 0
#   Max: 1
#   Stddev: 0.44491675228584093
#
# Column: image_msg_type_illuminating
#   Count: 246745
#   Mean: 0.22270360088350322
#   Min: 0
#   Max: 1
#   Stddev: 0.41606178459577625
#
# Column: cta_msg_type_illuminating
#   Count: 246745
#   Mean: 0.5727694583476869
#   Min: 0
#   Max: 1
#   Stddev: 0.494677266171149
#
# Column: engagement_cta_subtype_illuminating
#   Count: 246745
#   Mean: 0.12486980485926767
#   Min: 0
#   Max: 1
#   Stddev: 0.33057189773339457
#
# Column: fundraising_cta_subtype_illuminating
#   Count: 246745
#   Mean: 0.22848689943058623
#   Min: 0
#   Max: 1
#   Stddev: 0.41985872700996557
#
# Column: voting_cta_subtype_illuminating
#   Count: 246745
#   Mean: 0.1438448600782184
#   Min: 0
#   Max: 1
#   Stddev: 0.35093306401909335
#
# Column: covid_topic_illuminating
#   Count: 246745
#   Mean: 0.024875884009807697
#   Min: 0
#   Max: 1
#   Stddev: 0.15574714351540456
#
# Column: economy_topic_illuminating
#   Count: 246745
#   Mean: 0.12212202881517356
#   Min: 0
#   Max: 1
#   Stddev: 0.3274273558898461
#
# Column: education_topic_illuminating
#   Count: 246745
#   Mean: 0.01432653143934021
#   Min: 0
#   Max: 1
#   Stddev: 0.11883324100080564
#
# Column: environment_topic_illuminating
#   Count: 246745
#   Mean: 0.02124865752092241
#   Min: 0
#   Max: 1
#   Stddev: 0.14421246950536118
#
# Column: foreign_policy_topic_illuminating
#   Count: 246745
#   Mean: 0.005264544367667025
#   Min: 0
#   Max: 1
#   Stddev: 0.07236608434896528
#
# Column: governance_topic_illuminating
#   Count: 246745
#   Mean: 0.025641856977851627
#   Min: 0
#   Max: 1
#   Stddev: 0.15806471271206604
#
# Column: health_topic_illuminating
#   Count: 246745
#   Mean: 0.10918964923301384
#   Min: 0
#   Max: 1
#   Stddev: 0.31187764257247813
#
# Column: immigration_topic_illuminating
#   Count: 246745
#   Mean: 0.03356906928205232
#   Min: 0
#   Max: 1
#   Stddev: 0.1801175126153678
#
# Column: lgbtq_issues_topic_illuminating
#   Count: 246745
#   Mean: 0.0032300553202699142
#   Min: 0
#   Max: 1
#   Stddev: 0.05674182858640464
#
# Column: military_topic_illuminating
#   Count: 246745
#   Mean: 0.002176335893331172
#   Min: 0
#   Max: 1
#   Stddev: 0.0466005177700088
#
# Column: race_and_ethnicity_topic_illuminating
#   Count: 246745
#   Mean: 0.01243388923787716
#   Min: 0
#   Max: 1
#   Stddev: 0.11081217172130094
#
# Column: safety_topic_illuminating
#   Count: 246745
#   Mean: 0.03372307442906645
#   Min: 0
#   Max: 1
#   Stddev: 0.18051581854071774
#
# Column: social_and_cultural_topic_illuminating
#   Count: 246745
#   Mean: 0.10583801090194331
#   Min: 0
#   Max: 1
#   Stddev: 0.3076308012712654
#
# Column: technology_and_privacy_topic_illuminating
#   Count: 246745
#   Mean: 0.0011550386026059293
#   Min: 0
#   Max: 1
#   Stddev: 0.033966294530709096
#
# Column: womens_issue_topic_illuminating
#   Count: 246745
#   Mean: 0.08090944092078867
#   Min: 0
#   Max: 1
#   Stddev: 0.2726965431908306
#
# Column: incivility_illuminating
#   Count: 246745
#   Mean: 0.18752558309185596
#   Min: 0
#   Max: 1
#   Stddev: 0.39033364735690335
#
# Column: freefair_illuminating
#   Count: 246745
#   Mean: 0.006415530203246266
#   Min: 0
#   Max: 1
#   Stddev: 0.07983982095047254
#
# Column: fraud_illuminating
#   Count: 246745
#   Mean: 0.0026383513343735433
#   Min: 0
#   Max: 1
#   Stddev: 0.051297184143630825

# %%
import polars as pl

def analyze_polars_grouped(df: pl.DataFrame, group_cols: list[str]):
    print(f"\n===== Grouped Analysis by {group_cols} =====\n")

    # Get a list of other columns (non-grouping)
    other_cols = [col for col in df.columns if col not in group_cols]

    # Group the dataframe
    grouped = df.group_by(group_cols)

    # Loop over each group - limit to first 3
    for i, (group_key, group_df) in enumerate(grouped):
        if i >= 3:
            break

        print(f"Group: {group_key}")

        for col in other_cols:
            col_data = group_df[col].drop_nulls()

            print(f"  Column: {col}")
            if col_data.is_empty():
                print("     No data")
                continue

            if col_data.dtype.is_numeric():
                print(f"    Count: {col_data.len()}")
                print(f"    Mean: {col_data.mean()}")
                print(f"    Min: {col_data.min()}")
                print(f"    Max: {col_data.max()}")
                print(f"    Stddev: {col_data.std()}")
            else:
                unique_vals = col_data.unique()
                print(f"    Count: {col_data.len()}")
                print(f"    Unique values: {unique_vals.len()}")
                # Get top value cleanly
                freq_df = col_data.value_counts().sort("count", descending=True)
                top_val = freq_df[0][col].item()
                top_count = freq_df[0]["count"].item()
                print(f"    Most frequent: {top_val} (appears {top_count} times)")
        print("-" * 60)

# %%
analyze_polars_grouped(df_ads, ['page_id'])
analyze_polars_grouped(df_ads, ['page_id', 'ad_id'])
# Out:
# ===== Grouped Analysis by ['page_id'] =====
#
# Group: ('c26f0376627243618aee5b03d8ff810687884c865b6ed8d0932e8d04d76cad3b',)
#   Column: ad_id
#     Count: 4
#     Unique values: 4
#     Most frequent: d42837ff3c614804eda983270e1e75448ced427a833340831ea70ed9dfc100c8 (appears 1 times)
#   Column: ad_creation_time
#     Count: 4
#     Unique values: 2
#     Most frequent: 2024-08-20 (appears 3 times)
#   Column: bylines
#     Count: 4
#     Unique values: 1
#     Most frequent: JASMINE FOR US (appears 4 times)
#   Column: currency
#     Count: 4
#     Unique values: 1
#     Most frequent: USD (appears 4 times)
#   Column: delivery_by_region
#     Count: 4
#     Unique values: 4
#     Most frequent: {'Alabama': {'spend': 1, 'impressions': 77}, 'South Carolina': {'spend': 2, 'impressions': 100}, 'New Jersey': {'spend': 3, 'impressions': 182}, 'New Mexico': {'spend': 1, 'impressions': 73}, 'New York': {'spend': 7, 'impressions': 365}, 'North Carolina': {'spend': 4, 'impressions': 246}, 'North Dakota': {'spend': 0, 'impressions': 16}, 'Ohio': {'spend': 5, 'impressions': 253}, 'Oklahoma': {'spend': 1, 'impressions': 59}, 'Oregon': {'spend': 2, 'impressions': 118}, 'Pennsylvania': {'spend': 4, 'impressions': 237}, 'Rhode Island': {'spend': 0, 'impressions': 26}, 'South Dakota': {'spend': 0, 'impressions': 19}, 'Nevada': {'spend': 1, 'impressions': 66}, 'Tennessee': {'spend': 3, 'impressions': 153}, 'Texas': {'spend': 19, 'impressions': 976}, 'Utah': {'spend': 0, 'impressions': 42}, 'Vermont': {'spend': 0, 'impressions': 24}, 'Virginia': {'spend': 4, 'impressions': 215}, 'Washington': {'spend': 3, 'impressions': 188}, 'Washington, District of Columbia': {'spend': 0, 'impressions': 20}, 'West Virginia': {'spend': 0, 'impressions': 22}, 'Wisconsin': {'spend': 1, 'impressions': 98}, 'New Hampshire': {'spend': 0, 'impressions': 27}, 'Nebraska': {'spend': 0, 'impressions': 30}, 'Alaska': {'spend': 0, 'impressions': 20}, 'Illinois': {'spend': 5, 'impressions': 284}, 'Arizona': {'spend': 3, 'impressions': 181}, 'Arkansas': {'spend': 0, 'impressions': 42}, 'California': {'spend': 17, 'impressions': 885}, 'Colorado': {'spend': 2, 'impressions': 145}, 'Connecticut': {'spend': 1, 'impressions': 67}, 'Delaware': {'spend': 0, 'impressions': 20}, 'Florida': {'spend': 11, 'impressions': 565}, 'Georgia': {'spend': 5, 'impressions': 283}, 'Hawaii': {'spend': 0, 'impressions': 40}, 'Idaho': {'spend': 0, 'impressions': 27}, 'Indiana': {'spend': 2, 'impressions': 146}, 'Montana': {'spend': 0, 'impressions': 20}, 'Iowa': {'spend': 1, 'impressions': 56}, 'Kansas': {'spend': 1, 'impressions': 69}, 'Kentucky': {'spend': 1, 'impressions': 85}, 'Louisiana': {'spend': 1, 'impressions': 78}, 'Maine': {'spend': 0, 'impressions': 29}, 'Maryland': {'spend': 3, 'impressions': 152}, 'Massachusetts': {'spend': 2, 'impressions': 148}, 'Michigan': {'spend': 4, 'impressions': 214}, 'Minnesota': {'spend': 2, 'impressions': 100}, 'Mississippi': {'spend': 0, 'impressions': 29}, 'Missouri': {'spend': 2, 'impressions': 146}, 'Wyoming': {'spend': 0, 'impressions': 8}} (appears 1 times)
#   Column: demographic_distribution
#     Count: 4
#     Unique values: 4
#     Most frequent: {'female_18-24': {'spend': 3, 'impressions': 161}, 'male_45-54': {'spend': 64, 'impressions': 3115}, 'male_65+': {'spend': 181, 'impressions': 8828}, 'female_65+': {'spend': 628, 'impressions': 30547}, 'unknown_55-64': {'spend': 4, 'impressions': 241}, 'male_55-64': {'spend': 134, 'impressions': 6533}, 'female_55-64': {'spend': 409, 'impressions': 19911}, 'unknown_45-54': {'spend': 2, 'impressions': 103}, 'female_45-54': {'spend': 192, 'impressions': 9341}, 'male_18-24': {'spend': 2, 'impressions': 101}, 'unknown_35-44': {'spend': 1, 'impressions': 64}, 'male_35-44': {'spend': 27, 'impressions': 1354}, 'female_35-44': {'spend': 61, 'impressions': 2993}, 'unknown_25-34': {'spend': 0, 'impressions': 23}, 'male_25-34': {'spend': 9, 'impressions': 481}, 'female_25-34': {'spend': 16, 'impressions': 811}, 'unknown_18-24': {'spend': 0, 'impressions': 9}, 'unknown_65+': {'spend': 7, 'impressions': 375}} (appears 1 times)
#   Column: estimated_audience_size
#     Count: 4
#     Mean: 1000001.0
#     Min: 1000001
#     Max: 1000001
#     Stddev: 0.0
#   Column: estimated_impressions
#     Count: 4
#     Mean: 55624.0
#     Min: 7499
#     Max: 112499
#     Stddev: 51209.33345917845
#   Column: estimated_spend
#     Count: 4
#     Mean: 1224.0
#     Min: 149
#     Max: 2749
#     Stddev: 1252.663828274237
#   Column: publisher_platforms
#     Count: 4
#     Unique values: 1
#     Most frequent: ['facebook', 'instagram'] (appears 4 times)
#   Column: illuminating_scored_message
#     Count: 4
#     Unique values: 2
#     Most frequent: ed76d7650912fe870d7377ed34450376578f066d6ecb78bd0526f6d84aa82aa6 (appears 2 times)
#   Column: illuminating_mentions
#     Count: 4
#     Unique values: 2
#     Most frequent: ['Kamala Harris'] (appears 3 times)
#   Column: scam_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: election_integrity_Truth_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: advocacy_msg_type_illuminating
#     Count: 4
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: issue_msg_type_illuminating
#     Count: 4
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: attack_msg_type_illuminating
#     Count: 4
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: image_msg_type_illuminating
#     Count: 4
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: cta_msg_type_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: engagement_cta_subtype_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: fundraising_cta_subtype_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: voting_cta_subtype_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: covid_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: economy_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: education_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: environment_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: foreign_policy_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: governance_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: health_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: immigration_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: lgbtq_issues_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: military_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: race_and_ethnicity_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: safety_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: social_and_cultural_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: technology_and_privacy_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: womens_issue_topic_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: incivility_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: freefair_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: fraud_illuminating
#     Count: 4
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
# ------------------------------------------------------------
# Group: ('1279797efa946b56e8e7587b50961a58fa4c7723b6add2b763e7da2ffe87072e',)
#   Column: ad_id
#     Count: 5
#     Unique values: 5
#     Most frequent: a5677ae63c5a417be86d13c1feb8dab4acde2b2fed205560805b3fdf0e05abdf (appears 1 times)
#   Column: ad_creation_time
#     Count: 5
#     Unique values: 3
#     Most frequent: 2024-02-25 (appears 3 times)
#   Column: bylines
#     Count: 5
#     Unique values: 1
#     Most frequent: Vote Joe Finn (appears 5 times)
#   Column: currency
#     Count: 5
#     Unique values: 1
#     Most frequent: USD (appears 5 times)
#   Column: delivery_by_region
#     Count: 5
#     Unique values: 5
#     Most frequent: {'Massachusetts': {'spend': 49, 'impressions': 4499}} (appears 1 times)
#   Column: demographic_distribution
#     Count: 5
#     Unique values: 5
#     Most frequent: {'unknown_55-64': {'spend': 0, 'impressions': 11}, 'male_18-24': {'spend': 2, 'impressions': 557}, 'unknown_18-24': {'spend': 0, 'impressions': 35}, 'unknown_45-54': {'spend': 0, 'impressions': 11}, 'female_45-54': {'spend': 2, 'impressions': 675}, 'female_25-34': {'spend': 2, 'impressions': 616}, 'female_55-64': {'spend': 4, 'impressions': 1174}, 'female_65+': {'spend': 3, 'impressions': 830}, 'female_18-24': {'spend': 1, 'impressions': 296}, 'unknown_25-34': {'spend': 0, 'impressions': 11}, 'male_45-54': {'spend': 5, 'impressions': 1423}, 'male_35-44': {'spend': 4, 'impressions': 1257}, 'male_25-34': {'spend': 5, 'impressions': 1470}, 'male_55-64': {'spend': 7, 'impressions': 2015}, 'male_65+': {'spend': 5, 'impressions': 1399}, 'female_35-44': {'spend': 2, 'impressions': 652}, 'unknown_35-44': {'spend': 0, 'impressions': 23}, 'unknown_65+': {'spend': 0, 'impressions': 35}} (appears 1 times)
#   Column: estimated_audience_size
#     Count: 5
#     Mean: 62320.0
#     Min: 550
#     Max: 300000
#     Stddev: 132897.46329407496
#   Column: estimated_impressions
#     Count: 5
#     Mean: 12699.0
#     Min: 1499
#     Max: 27499
#     Stddev: 10425.929215182692
#   Column: estimated_spend
#     Count: 5
#     Mean: 69.0
#     Min: 49
#     Max: 149
#     Stddev: 44.721359549995796
#   Column: publisher_platforms
#     Count: 5
#     Unique values: 1
#     Most frequent: ['facebook', 'instagram'] (appears 5 times)
#   Column: illuminating_scored_message
#     Count: 5
#     Unique values: 1
#     Most frequent: 8fa5ad74b0bfabe22639fe781f170569087d89b9b6a9f278c951805953183838 (appears 5 times)
#   Column: illuminating_mentions
#     Count: 5
#     Unique values: 1
#     Most frequent: ['Donald Trump', 'Nikki Haley'] (appears 5 times)
#   Column: scam_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: election_integrity_Truth_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: advocacy_msg_type_illuminating
#     Count: 5
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: issue_msg_type_illuminating
#     Count: 5
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: attack_msg_type_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: image_msg_type_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: cta_msg_type_illuminating
#     Count: 5
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: engagement_cta_subtype_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: fundraising_cta_subtype_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: voting_cta_subtype_illuminating
#     Count: 5
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: covid_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: economy_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: education_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: environment_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: foreign_policy_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: governance_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: health_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: immigration_topic_illuminating
#     Count: 5
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: lgbtq_issues_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: military_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: race_and_ethnicity_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: safety_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: social_and_cultural_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: technology_and_privacy_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: womens_issue_topic_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: incivility_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: freefair_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: fraud_illuminating
#     Count: 5
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
# ------------------------------------------------------------
# Group: ('9764c4fe2e3c9fb8e0841d4d46df15dd1b3a419838acc44dc4767883d9eedb31',)
#   Column: ad_id
#     Count: 24
#     Unique values: 24
#     Most frequent: ce01d4be0dcc6f918e9b3a42a611df95f17e0763a2707efad19bd3d61ca1eaa2 (appears 1 times)
#   Column: ad_creation_time
#     Count: 24
#     Unique values: 13
#     Most frequent: 2024-08-06 (appears 3 times)
#   Column: bylines
#     Count: 24
#     Unique values: 1
#     Most frequent: Growing and Going (appears 24 times)
#   Column: currency
#     Count: 24
#     Unique values: 1
#     Most frequent: USD (appears 24 times)
#   Column: delivery_by_region
#     Count: 24
#     Unique values: 24
#     Most frequent: {} (appears 1 times)
#   Column: demographic_distribution
#     Count: 24
#     Unique values: 24
#     Most frequent: {'unknown_55-64': {'spend': 0, 'impressions': 6}, 'unknown_65+': {'spend': 0, 'impressions': 17}, 'female_25-34': {'spend': 0, 'impressions': 15}, 'male_35-44': {'spend': 1, 'impressions': 52}, 'female_45-54': {'spend': 1, 'impressions': 87}, 'male_25-34': {'spend': 0, 'impressions': 20}, 'male_65+': {'spend': 12, 'impressions': 630}, 'male_45-54': {'spend': 2, 'impressions': 150}, 'female_55-64': {'spend': 6, 'impressions': 323}, 'female_65+': {'spend': 15, 'impressions': 768}, 'female_35-44': {'spend': 0, 'impressions': 32}, 'male_55-64': {'spend': 7, 'impressions': 385}, 'unknown_25-34': {'spend': 0, 'impressions': 1}, 'unknown_35-44': {'spend': 0, 'impressions': 2}, 'unknown_45-54': {'spend': 0, 'impressions': 2}} (appears 1 times)
#   Column: estimated_audience_size
#     Count: 24
#     Mean: 1000001.0
#     Min: 1000001
#     Max: 1000001
#     Stddev: 0.0
#   Column: estimated_impressions
#     Count: 24
#     Mean: 2207.3333333333335
#     Min: 499
#     Max: 6499
#     Stddev: 1944.4271910897753
#   Column: estimated_spend
#     Count: 24
#     Mean: 53.166666666666664
#     Min: 49
#     Max: 149
#     Stddev: 20.412414523193156
#   Column: publisher_platforms
#     Count: 24
#     Unique values: 2
#     Most frequent: ['facebook', 'instagram'] (appears 17 times)
#   Column: illuminating_scored_message
#     Count: 24
#     Unique values: 14
#     Most frequent: 7eba23a9ab2d61f1a1110519641735ce8da24d0dcad18ce1a3a30a2223f6987e (appears 4 times)
#   Column: illuminating_mentions
#     Count: 24
#     Unique values: 2
#     Most frequent: ['Kamala Harris', 'Tim Walz'] (appears 14 times)
#   Column: scam_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: election_integrity_Truth_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: advocacy_msg_type_illuminating
#     Count: 24
#     Mean: 0.6666666666666666
#     Min: 0
#     Max: 1
#     Stddev: 0.48154341234307685
#   Column: issue_msg_type_illuminating
#     Count: 24
#     Mean: 0.25
#     Min: 0
#     Max: 1
#     Stddev: 0.4423258684646914
#   Column: attack_msg_type_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: image_msg_type_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: cta_msg_type_illuminating
#     Count: 24
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: 0.0
#   Column: engagement_cta_subtype_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: fundraising_cta_subtype_illuminating
#     Count: 24
#     Mean: 0.3333333333333333
#     Min: 0
#     Max: 1
#     Stddev: 0.4815434123430767
#   Column: voting_cta_subtype_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: covid_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: economy_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: education_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: environment_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: foreign_policy_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: governance_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: health_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: immigration_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: lgbtq_issues_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: military_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: race_and_ethnicity_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: safety_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: social_and_cultural_topic_illuminating
#     Count: 24
#     Mean: 0.08333333333333333
#     Min: 0
#     Max: 1
#     Stddev: 0.28232985128663995
#   Column: technology_and_privacy_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: womens_issue_topic_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: incivility_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: freefair_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
#   Column: fraud_illuminating
#     Count: 24
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: 0.0
# ------------------------------------------------------------
#
# ===== Grouped Analysis by ['page_id', 'ad_id'] =====
#
# Group: ('e3342051b60393770363ffc02946a0f76bc3e4155190d1f05fb0277b34bf6480', '141bacdb9b2f96a51d88014043667cc140914b8a22d5d41449ff5a07741a2191')
#   Column: ad_creation_time
#     Count: 1
#     Unique values: 1
#     Most frequent: 2024-10-10 (appears 1 times)
#   Column: bylines
#     Count: 1
#     Unique values: 1
#     Most frequent: DONALD J. TRUMP FOR PRESIDENT 2024, INC. (appears 1 times)
#   Column: currency
#     Count: 1
#     Unique values: 1
#     Most frequent: USD (appears 1 times)
#   Column: delivery_by_region
#     Count: 1
#     Unique values: 1
#     Most frequent: {} (appears 1 times)
#   Column: demographic_distribution
#     Count: 1
#     Unique values: 1
#     Most frequent: {} (appears 1 times)
#   Column: estimated_audience_size
#     Count: 1
#     Mean: 550.0
#     Min: 550
#     Max: 550
#     Stddev: None
#   Column: estimated_impressions
#     Count: 1
#     Mean: 499.0
#     Min: 499
#     Max: 499
#     Stddev: None
#   Column: estimated_spend
#     Count: 1
#     Mean: 49.0
#     Min: 49
#     Max: 49
#     Stddev: None
#   Column: publisher_platforms
#     Count: 1
#     Unique values: 1
#     Most frequent: ['instagram'] (appears 1 times)
#   Column: illuminating_scored_message
#     Count: 1
#     Unique values: 1
#     Most frequent: 8e1144f0b13549c2652e19f6dd1ae523956a19671c5e4383a31f09d9325f1239 (appears 1 times)
#   Column: illuminating_mentions
#     Count: 1
#     Unique values: 1
#     Most frequent: [] (appears 1 times)
#   Column: scam_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: election_integrity_Truth_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: advocacy_msg_type_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: issue_msg_type_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: attack_msg_type_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: image_msg_type_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: cta_msg_type_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: engagement_cta_subtype_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: fundraising_cta_subtype_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: voting_cta_subtype_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: covid_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: economy_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: education_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: environment_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: foreign_policy_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: governance_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: health_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: immigration_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: lgbtq_issues_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: military_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: race_and_ethnicity_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: safety_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: social_and_cultural_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: technology_and_privacy_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: womens_issue_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: incivility_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: freefair_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: fraud_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
# ------------------------------------------------------------
# Group: ('9090e0cc85bfd7909ff73ed7796f0c5bfc0b34007657225fcdcfb278821dad2c', 'a10f59d4922c3ee2ed521b5114568b6299b5715e87082f93a9bd9f5e88beb028')
#   Column: ad_creation_time
#     Count: 1
#     Unique values: 1
#     Most frequent: 2024-09-10 (appears 1 times)
#   Column: bylines
#     Count: 1
#     Unique values: 1
#     Most frequent: The Keystone (appears 1 times)
#   Column: currency
#     Count: 1
#     Unique values: 1
#     Most frequent: USD (appears 1 times)
#   Column: delivery_by_region
#     Count: 1
#     Unique values: 1
#     Most frequent: {'Pennsylvania': {'spend': 4525, 'impressions': 226320}, 'Nevada': {'spend': 8, 'impressions': 406}, 'New Hampshire': {'spend': 7, 'impressions': 360}, 'New Jersey': {'spend': 235, 'impressions': 11800}, 'New Mexico': {'spend': 5, 'impressions': 253}, 'New York': {'spend': 445, 'impressions': 22288}, 'North Carolina': {'spend': 68, 'impressions': 3412}, 'North Dakota': {'spend': 0, 'impressions': 47}, 'Ohio': {'spend': 53, 'impressions': 2679}, 'Oklahoma': {'spend': 3, 'impressions': 195}, 'Oregon': {'spend': 16, 'impressions': 830}, 'Rhode Island': {'spend': 9, 'impressions': 460}, 'Montana': {'spend': 3, 'impressions': 167}, 'South Carolina': {'spend': 22, 'impressions': 1133}, 'South Dakota': {'spend': 0, 'impressions': 35}, 'Tennessee': {'spend': 17, 'impressions': 866}, 'Texas': {'spend': 59, 'impressions': 2999}, 'Utah': {'spend': 6, 'impressions': 329}, 'Vermont': {'spend': 9, 'impressions': 470}, 'Virginia': {'spend': 79, 'impressions': 3990}, 'Washington': {'spend': 29, 'impressions': 1500}, 'West Virginia': {'spend': 13, 'impressions': 667}, 'Wisconsin': {'spend': 12, 'impressions': 635}, 'Nebraska': {'spend': 2, 'impressions': 118}, 'Missouri': {'spend': 8, 'impressions': 449}, 'Alabama': {'spend': 6, 'impressions': 303}, 'Hawaii': {'spend': 5, 'impressions': 263}, 'Alaska': {'spend': 2, 'impressions': 123}, 'Arizona': {'spend': 24, 'impressions': 1239}, 'Arkansas': {'spend': 2, 'impressions': 144}, 'California': {'spend': 161, 'impressions': 8095}, 'Colorado': {'spend': 41, 'impressions': 2095}, 'Connecticut': {'spend': 26, 'impressions': 1324}, 'Delaware': {'spend': 53, 'impressions': 2662}, 'Washington, District of Columbia': {'spend': 61, 'impressions': 3059}, 'Florida': {'spend': 79, 'impressions': 3984}, 'Georgia': {'spend': 48, 'impressions': 2436}, 'Idaho': {'spend': 2, 'impressions': 113}, 'Mississippi': {'spend': 2, 'impressions': 107}, 'Illinois': {'spend': 49, 'impressions': 2486}, 'Indiana': {'spend': 12, 'impressions': 624}, 'Iowa': {'spend': 3, 'impressions': 161}, 'Kansas': {'spend': 3, 'impressions': 167}, 'Kentucky': {'spend': 6, 'impressions': 330}, 'Louisiana': {'spend': 7, 'impressions': 399}, 'Maine': {'spend': 10, 'impressions': 505}, 'Maryland': {'spend': 95, 'impressions': 4768}, 'Massachusetts': {'spend': 80, 'impressions': 4018}, 'Michigan': {'spend': 21, 'impressions': 1092}, 'Minnesota': {'spend': 11, 'impressions': 558}, 'Wyoming': {'spend': 1, 'impressions': 82}} (appears 1 times)
#   Column: demographic_distribution
#     Count: 1
#     Unique values: 1
#     Most frequent: {'unknown_65+': {'spend': 1, 'impressions': 75}, 'male_35-44': {'spend': 488, 'impressions': 24425}, 'unknown_25-34': {'spend': 45, 'impressions': 2264}, 'female_65+': {'spend': 40, 'impressions': 2022}, 'unknown_55-64': {'spend': 1, 'impressions': 57}, 'female_55-64': {'spend': 84, 'impressions': 4237}, 'female_35-44': {'spend': 699, 'impressions': 34959}, 'unknown_18-24': {'spend': 32, 'impressions': 1636}, 'female_18-24': {'spend': 1126, 'impressions': 56319}, 'unknown_35-44': {'spend': 13, 'impressions': 681}, 'male_18-24': {'spend': 493, 'impressions': 24703}, 'female_25-34': {'spend': 2100, 'impressions': 105040}, 'male_25-34': {'spend': 1139, 'impressions': 57006}, 'male_65+': {'spend': 29, 'impressions': 1496}, 'male_55-64': {'spend': 42, 'impressions': 2109}, 'male_45-54': {'spend': 60, 'impressions': 3047}, 'female_45-54': {'spend': 96, 'impressions': 4841}, 'unknown_45-54': {'spend': 1, 'impressions': 73}} (appears 1 times)
#   Column: estimated_audience_size
#     Count: 1
#     Mean: 750000.0
#     Min: 750000
#     Max: 750000
#     Stddev: None
#   Column: estimated_impressions
#     Count: 1
#     Mean: 324999.0
#     Min: 324999
#     Max: 324999
#     Stddev: None
#   Column: estimated_spend
#     Count: 1
#     Mean: 6499.0
#     Min: 6499
#     Max: 6499
#     Stddev: None
#   Column: publisher_platforms
#     Count: 1
#     Unique values: 1
#     Most frequent: ['facebook', 'instagram'] (appears 1 times)
#   Column: illuminating_scored_message
#     Count: 1
#     Unique values: 1
#     Most frequent: 74fab98b9a1314d1a69d4675ff4698ff13607605c2c272a99c120993c49ac6b2 (appears 1 times)
#   Column: illuminating_mentions
#     Count: 1
#     Unique values: 1
#     Most frequent: ['Kamala Harris'] (appears 1 times)
#   Column: scam_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: election_integrity_Truth_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: advocacy_msg_type_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: issue_msg_type_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: attack_msg_type_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: image_msg_type_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: cta_msg_type_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: engagement_cta_subtype_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: fundraising_cta_subtype_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: voting_cta_subtype_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: covid_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: economy_topic_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: education_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: environment_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: foreign_policy_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: governance_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: health_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: immigration_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: lgbtq_issues_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: military_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: race_and_ethnicity_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: safety_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: social_and_cultural_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: technology_and_privacy_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: womens_issue_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: incivility_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: freefair_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: fraud_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
# ------------------------------------------------------------
# Group: ('53a74049e9ff3c4276f15cb0dc6d35c93e830c25a5eee6f3d914321922913415', '07f070d58653525356c741c9e79adf25215cad6a673a58e3776c260cd53f34cc')
#   Column: ad_creation_time
#     Count: 1
#     Unique values: 1
#     Most frequent: 2024-10-23 (appears 1 times)
#   Column: bylines
#     Count: 1
#     Unique values: 1
#     Most frequent: Working America (appears 1 times)
#   Column: currency
#     Count: 1
#     Unique values: 1
#     Most frequent: USD (appears 1 times)
#   Column: delivery_by_region
#     Count: 1
#     Unique values: 1
#     Most frequent: {'Alabama': {'spend': 0, 'impressions': 20}, 'South Carolina': {'spend': 0, 'impressions': 20}, 'New Jersey': {'spend': 0, 'impressions': 16}, 'New Mexico': {'spend': 0, 'impressions': 87}, 'New York': {'spend': 0, 'impressions': 56}, 'North Carolina': {'spend': 0, 'impressions': 45}, 'North Dakota': {'spend': 0, 'impressions': 2}, 'Ohio': {'spend': 0, 'impressions': 58}, 'Oklahoma': {'spend': 0, 'impressions': 26}, 'Oregon': {'spend': 0, 'impressions': 48}, 'Pennsylvania': {'spend': 0, 'impressions': 40}, 'Rhode Island': {'spend': 0, 'impressions': 5}, 'South Dakota': {'spend': 0, 'impressions': 5}, 'Nevada': {'spend': 0, 'impressions': 66}, 'Tennessee': {'spend': 0, 'impressions': 30}, 'Texas': {'spend': 1, 'impressions': 186}, 'Utah': {'spend': 0, 'impressions': 23}, 'Vermont': {'spend': 0, 'impressions': 4}, 'Virginia': {'spend': 0, 'impressions': 27}, 'Washington': {'spend': 0, 'impressions': 86}, 'Washington, District of Columbia': {'spend': 0, 'impressions': 8}, 'West Virginia': {'spend': 0, 'impressions': 11}, 'Wisconsin': {'spend': 0, 'impressions': 41}, 'New Hampshire': {'spend': 0, 'impressions': 8}, 'Nebraska': {'spend': 0, 'impressions': 12}, 'Alaska': {'spend': 0, 'impressions': 9}, 'Illinois': {'spend': 0, 'impressions': 87}, 'Arizona': {'spend': 31, 'impressions': 3561}, 'Arkansas': {'spend': 0, 'impressions': 20}, 'California': {'spend': 2, 'impressions': 264}, 'Colorado': {'spend': 1, 'impressions': 125}, 'Connecticut': {'spend': 0, 'impressions': 12}, 'Delaware': {'spend': 0, 'impressions': 1}, 'Florida': {'spend': 0, 'impressions': 75}, 'Georgia': {'spend': 0, 'impressions': 29}, 'Hawaii': {'spend': 0, 'impressions': 12}, 'Idaho': {'spend': 0, 'impressions': 27}, 'Indiana': {'spend': 0, 'impressions': 44}, 'Montana': {'spend': 0, 'impressions': 5}, 'Iowa': {'spend': 0, 'impressions': 38}, 'Kansas': {'spend': 0, 'impressions': 34}, 'Kentucky': {'spend': 0, 'impressions': 18}, 'Louisiana': {'spend': 0, 'impressions': 15}, 'Maine': {'spend': 0, 'impressions': 4}, 'Maryland': {'spend': 0, 'impressions': 15}, 'Massachusetts': {'spend': 0, 'impressions': 19}, 'Michigan': {'spend': 0, 'impressions': 45}, 'Minnesota': {'spend': 0, 'impressions': 47}, 'Mississippi': {'spend': 0, 'impressions': 2}, 'Missouri': {'spend': 0, 'impressions': 31}, 'Wyoming': {'spend': 0, 'impressions': 1}} (appears 1 times)
#   Column: demographic_distribution
#     Count: 1
#     Unique values: 1
#     Most frequent: {'female_18-24': {'spend': 2, 'impressions': 231}, 'male_45-54': {'spend': 3, 'impressions': 386}, 'male_65+': {'spend': 2, 'impressions': 308}, 'female_65+': {'spend': 3, 'impressions': 399}, 'unknown_55-64': {'spend': 0, 'impressions': 4}, 'male_55-64': {'spend': 3, 'impressions': 364}, 'female_55-64': {'spend': 3, 'impressions': 394}, 'unknown_45-54': {'spend': 0, 'impressions': 2}, 'female_45-54': {'spend': 4, 'impressions': 496}, 'male_18-24': {'spend': 1, 'impressions': 133}, 'unknown_35-44': {'spend': 0, 'impressions': 14}, 'male_35-44': {'spend': 5, 'impressions': 597}, 'female_35-44': {'spend': 6, 'impressions': 776}, 'unknown_25-34': {'spend': 0, 'impressions': 9}, 'male_25-34': {'spend': 4, 'impressions': 559}, 'female_25-34': {'spend': 7, 'impressions': 806}, 'unknown_18-24': {'spend': 0, 'impressions': 8}, 'unknown_65+': {'spend': 0, 'impressions': 4}} (appears 1 times)
#   Column: estimated_audience_size
#     Count: 1
#     Mean: 750000.0
#     Min: 750000
#     Max: 750000
#     Stddev: None
#   Column: estimated_impressions
#     Count: 1
#     Mean: 5499.0
#     Min: 5499
#     Max: 5499
#     Stddev: None
#   Column: estimated_spend
#     Count: 1
#     Mean: 49.0
#     Min: 49
#     Max: 49
#     Stddev: None
#   Column: publisher_platforms
#     Count: 1
#     Unique values: 1
#     Most frequent: ['facebook', 'instagram'] (appears 1 times)
#   Column: illuminating_scored_message
#     Count: 1
#     Unique values: 1
#     Most frequent: ddec5601c9599cad7531411c35aa5685d7dfc774ef35045b80bcb3103a81b1a1 (appears 1 times)
#   Column: illuminating_mentions
#     Count: 1
#     Unique values: 1
#     Most frequent: ['Kamala Harris'] (appears 1 times)
#   Column: scam_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: election_integrity_Truth_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: advocacy_msg_type_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: issue_msg_type_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: attack_msg_type_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: image_msg_type_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: cta_msg_type_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: engagement_cta_subtype_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: fundraising_cta_subtype_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: voting_cta_subtype_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: covid_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: economy_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: education_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: environment_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: foreign_policy_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: governance_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: health_topic_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: immigration_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: lgbtq_issues_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: military_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: race_and_ethnicity_topic_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: safety_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: social_and_cultural_topic_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: technology_and_privacy_topic_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: womens_issue_topic_illuminating
#     Count: 1
#     Mean: 1.0
#     Min: 1
#     Max: 1
#     Stddev: None
#   Column: incivility_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: freefair_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
#   Column: fraud_illuminating
#     Count: 1
#     Mean: 0.0
#     Min: 0
#     Max: 0
#     Stddev: None
# ------------------------------------------------------------
